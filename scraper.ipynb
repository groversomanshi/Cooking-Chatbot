# %%
# %pip install -U ddgs
from ddgs import DDGS
# Out:
# Collecting ddgs
#   Downloading ddgs-9.13.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: click>=8.1.8 in /Users/shubhan/anaconda3/envs/data_discovery/lib/python3.12/site-packages (from ddgs) (8.2.1)
# Collecting primp>=1.2.0 (from ddgs)
#   Downloading primp-1.2.2-cp310-abi3-macosx_10_12_x86_64.whl.metadata (3.6 kB)
# Collecting lxml>=4.9.4 (from ddgs)
#   Downloading lxml-6.0.2-cp312-cp312-macosx_10_13_x86_64.whl.metadata (3.6 kB)
# Downloading ddgs-9.13.0-py3-none-any.whl (46 kB)
# Downloading lxml-6.0.2-cp312-cp312-macosx_10_13_x86_64.whl (4.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 29.9 MB/s  0:00:00
# Downloading primp-1.2.2-cp310-abi3-macosx_10_12_x86_64.whl (4.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.4/4.4 MB 28.6 MB/s  0:00:00
# Installing collected packages: primp, lxml, ddgs
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3/3 [ddgs]2/3 [ddgs]
# Successfully installed ddgs-9.13.0 lxml-6.0.2 primp-1.2.2
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install easyocr
import easyocr
reader = easyocr.Reader(['en'])
# Out:
# Collecting easyocr
#   Downloading easyocr-1.7.2-py3-none-any.whl.metadata (10 kB)
# Collecting torch (from easyocr)
#   Downloading torch-2.2.2-cp312-none-macosx_10_9_x86_64.whl.metadata (25 kB)
# Collecting torchvision>=0.5 (from easyocr)
#   Downloading torchvision-0.17.2-cp312-cp312-macosx_10_13_x86_64.whl.metadata (6.6 kB)
# Collecting opencv-python-headless (from easyocr)
#   Downloading opencv_python_headless-4.13.0.92-cp37-abi3-macosx_14_0_x86_64.whl.metadata (19 kB)
# Requirement already satisfied: scipy in /Users/shubhan/anaconda3/envs/data_discovery/lib/python3.12/site-packages (from easyocr) (1.16.0)
# Requirement already satisfied: numpy in /Users/shubhan/anaconda3/envs/data_discovery/lib/python3.12/site-packages (from easyocr) (2.3.1)
# Requirement already satisfied: Pillow in /Users/shubhan/anaconda3/envs/data_discovery/lib/python3.12/site-packages (from easyocr) (12.1.1)
# Collecting scikit-image (from easyocr)
#   Downloading scikit_image-0.26.0-cp312-cp312-macosx_10_13_x86_64.whl.metadata (15 kB)
# Collecting python-bidi (from easyocr)
#   Downloading python_bidi-0.6.7-cp312-cp312-macosx_10_12_x86_64.whl.metadata (4.9 kB)
# Requirement already satisfied: PyYAML in /Users/shubhan/anaconda3/envs/data_discovery/lib/python3.12/site-packages (from easyocr) (6.0.2)
# Collecting Shapely (from easyocr)
#   Downloading shapely-2.1.2-cp312-cp312-macosx_10_13_x86_64.whl.metadata (6.8 kB)
# Collecting pyclipper (from easyocr)
#   Downloading pyclipper-1.4.0-cp312-cp312-macosx_10_13_x86_64.whl.metadata (8.6 kB)
# Collecting ninja (from easyocr)
#   Downloading ninja-1.13.0-py3-none-macosx_10_9_universal2.whl.metadata (5.1 kB)
# Requirement already satisfied: filelock in /Users/shubhan/anaconda3/envs/data_discovery/lib/python3.12/site-packages (from torch->easyocr) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /Users/shubhan/anaconda3/envs/data_discovery/lib/python3.12/site-packages (from torch->easyocr) (4.15.0)
# Collecting sympy (from torch->easyocr)
#   Downloading sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: networkx in /Users/shubhan/anaconda3/envs/data_discovery/lib/python3.12/site-packages (from torch->easyocr) (3.4.2)
# Requirement already satisfied: jinja2 in /Users/shubhan/anaconda3/envs/data_discovery/lib/python3.12/site-packages (from torch->easyocr) (3.1.6)
# Requirement already satisfied: fsspec in /Users/shubhan/anaconda3/envs/data_discovery/lib/python3.12/site-packages (from torch->easyocr) (2024.12.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/shubhan/anaconda3/envs/data_discovery/lib/python3.12/site-packages (from jinja2->torch->easyocr) (3.0.2)
# Collecting imageio!=2.35.0,>=2.33 (from scikit-image->easyocr)
#   Downloading imageio-2.37.3-py3-none-any.whl.metadata (9.7 kB)
# Collecting tifffile>=2022.8.12 (from scikit-image->easyocr)
#   Downloading tifffile-2026.3.3-py3-none-any.whl.metadata (31 kB)
# Requirement already satisfied: packaging>=21 in /Users/shubhan/anaconda3/envs/data_discovery/lib/python3.12/site-packages (from scikit-image->easyocr) (25.0)
# Collecting lazy-loader>=0.4 (from scikit-image->easyocr)
#   Downloading lazy_loader-0.5-py3-none-any.whl.metadata (5.9 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy->torch->easyocr)
#   Downloading mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Downloading easyocr-1.7.2-py3-none-any.whl (2.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 23.2 MB/s  0:00:00
# Downloading torchvision-0.17.2-cp312-cp312-macosx_10_13_x86_64.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 25.7 MB/s  0:00:00
# Downloading torch-2.2.2-cp312-none-macosx_10_9_x86_64.whl (150.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 150.8/150.8 MB 42.8 MB/s  0:00:03m0:00:0100:01
# Downloading ninja-1.13.0-py3-none-macosx_10_9_universal2.whl (310 kB)
# Downloading opencv_python_headless-4.13.0.92-cp37-abi3-macosx_14_0_x86_64.whl (32.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.6/32.6 MB 42.3 MB/s  0:00:00 eta 0:00:01
# Downloading pyclipper-1.4.0-cp312-cp312-macosx_10_13_x86_64.whl (140 kB)
# Downloading python_bidi-0.6.7-cp312-cp312-macosx_10_12_x86_64.whl (272 kB)
# Downloading scikit_image-0.26.0-cp312-cp312-macosx_10_13_x86_64.whl (12.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 39.0 MB/s  0:00:00eta 0:00:01
# Downloading imageio-2.37.3-py3-none-any.whl (317 kB)
# Downloading lazy_loader-0.5-py3-none-any.whl (8.0 kB)
# Downloading tifffile-2026.3.3-py3-none-any.whl (243 kB)
# Downloading shapely-2.1.2-cp312-cp312-macosx_10_13_x86_64.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 12.1 MB/s  0:00:00
# Downloading sympy-1.14.0-py3-none-any.whl (6.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 40.4 MB/s  0:00:00
# Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 7.4 MB/s  0:00:00
# Installing collected packages: python-bidi, mpmath, tifffile, sympy, Shapely, pyclipper, opencv-python-headless, ninja, lazy-loader, imageio, torch, scikit-image, torchvision, easyocr
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14/14 [easyocr]3/14 [easyocr]ion]]-headless]
# Successfully installed Shapely-2.1.2 easyocr-1.7.2 imageio-2.37.3 lazy-loader-0.5 mpmath-1.3.0 ninja-1.13.0 opencv-python-headless-4.13.0.92 pyclipper-1.4.0 python-bidi-0.6.7 scikit-image-0.26.0 sympy-1.14.0 tifffile-2026.3.3 torch-2.2.2 torchvision-0.17.2
# Note: you may need to restart the kernel to use updated packages.
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.3.1 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/Users/shubhan/anaconda3/envs/data_discovery/lib/python3.12/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/Users/shubhan/anaconda3/envs/data_discovery/lib/python3.12/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/Users/shubhan/anaconda3/envs/data_discovery/lib/python3.12/site-packages/ipykernel/kernelapp.py", line 758, in start
#     self.io_loop.start()
#   File "/Users/shubhan/anaconda3/envs/data_discovery/lib/python3.12/site-packages/tornado/platform/asyncio.py", line 211, in start
#     self.asyncio_loop.run_forever()
#   File "/Users/shubhan/anaconda3/envs/data_discovery/lib/python3.12/asyncio/base_events.py", line 641, in run_forever
#     self._run_once()
#   File "/Users/shubhan/anaconda3/envs/data_discovery/lib/python3.12/asyncio/base_events.py", line 1987, in _run_once
#     handle._run()
#   File "/Users/shubhan/anaconda3/envs/data_discovery/lib/python3.12/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/Users/shubhan/anaconda3/envs/data_discovery/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 614, in shell_main
#     await self.dispatch_shell(msg, subshell_id=subshell_id)
#   File "/Users/shubhan/anaconda3/envs/data_discovery/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 471, in dispatch_shell
#     await result
#   File "/Users/shubhan/anaconda3/envs/data_discovery/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 366, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "/Users/shubhan/anaconda3/envs/data_discovery/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 827, in execute_request
#     reply_content = await reply_content
#   File "/Users/shubhan/anaconda3/envs/data_discovery/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 458, in do_execute
#     res = shell.run_cell(
#   File "/Users/shubhan/anaconda3/envs/data_discovery/lib/python3.12/site-packages/ipykernel/zmqshell.py", line 663, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/Users/shubhan/anaconda3/envs/data_discovery/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3116, in run_cell
#     result = self._run_cell(
#   File "/Users/shubhan/anaconda3/envs/data_discovery/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3171, in _run_cell
#     result = runner(coro)
#   File "/Users/shubhan/anaconda3/envs/data_discovery/lib/python3.12/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "/Users/shubhan/anaconda3/envs/data_discovery/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3394, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/Users/shubhan/anaconda3/envs/data_discovery/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3639, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/Users/shubhan/anaconda3/envs/data_discovery/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3699, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/var/folders/_v/ncwq304d761gb02f1n7x_2vr0000gn/T/ipykernel_91584/2514440875.py", line 2, in <module>
#     import easyocr
#   File "/Users/shubhan/anaconda3/envs/data_discovery/lib/python3.12/site-packages/easyocr/__init__.py", line 1, in <module>
#     from .easyocr import Reader
#   File "/Users/shubhan/anaconda3/envs/data_discovery/lib/python3.12/site-packages/easyocr/easyocr.py", line 3, in <module>
#     from .recognition import get_recognizer, get_text
#   File "/Users/shubhan/anaconda3/envs/data_discovery/lib/python3.12/site-packages/easyocr/recognition.py", line 2, in <module>
#     import torch
#   File "/Users/shubhan/anaconda3/envs/data_discovery/lib/python3.12/site-packages/torch/__init__.py", line 1477, in <module>
#     from .functional import *  # noqa: F403
#   File "/Users/shubhan/anaconda3/envs/data_discovery/lib/python3.12/site-packages/torch/functional.py", line 9, in <module>
#     import torch.nn.functional as F
#   File "/Users/shubhan/anaconda3/envs/data_discovery/lib/python3.12/site-packages/torch/nn/__init__.py", line 1, in <module>
#     from .modules import *  # noqa: F403
#   File "/Users/shubhan/anaconda3/envs/data_discovery/lib/python3.12/site-packages/torch/nn/modules/__init__.py", line 35, in <module>
#     from .transformer import TransformerEncoder, TransformerDecoder, \
#   File "/Users/shubhan/anaconda3/envs/data_discovery/lib/python3.12/site-packages/torch/nn/modules/transformer.py", line 20, in <module>
#     device: torch.device = torch.device(torch._C._get_default_device()),  # torch.device('cpu'),
# /Users/shubhan/anaconda3/envs/data_discovery/lib/python3.12/site-packages/torch/nn/modules/transformer.py:20: UserWarning: Failed to initialize NumPy: _ARRAY_API not found (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/torch/csrc/utils/tensor_numpy.cpp:84.)
#   device: torch.device = torch.device(torch._C._get_default_device()),  # torch.device('cpu'),
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# Downloading detection model, please wait. This may take several minutes depending upon your network connection.
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
# Downloading recognition model, please wait. This may take several minutes depending upon your network connection.
# Progress: |██████████████████████████████████████████████████| 100.0% Complete

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import os
import io
import requests
import time

from PIL import Image

# %%
import warnings
warnings.filterwarnings('ignore', category=DeprecationWarning)

# %%
def has_text(image_bytes):
  img = Image.open(io.BytesIO(image_bytes))
  results = reader.readtext(np.array(img))
  return len(results) > 0

# %%
def fetch_image_bytes(url):
    try:
        response = requests.get(url)
    except requests.RequestException:
        return None

    if response.status_code != 200:
        return None

    data = response.content
    if len(data) == 0:
        return None

    return data

# %% [markdown]
# # Categorized Ingredients

# %% [markdown]
# ### Drive File Access

# %%
from google.colab import drive
drive.mount('/content/gdrive')
PATH = '/content/gdrive/MyDrive/Scraped_Images'

# %%
df_1 = pd.read_parquet("/content/gdrive/My Drive/Colab Notebooks/test images/Food Ingredients Data/train-00000-of-00003.parquet")
df_2 = pd.read_parquet("/content/gdrive/My Drive/Colab Notebooks/test images/Food Ingredients Data/train-00001-of-00003.parquet")
df_3 = pd.read_parquet("/content/gdrive/My Drive/Colab Notebooks/test images/Food Ingredients Data/train-00002-of-00003.parquet")
df = pd.concat([df_1, df_2, df_3], axis=0)
df.head()

# %% [markdown]
# ### Local File Access

# %%
PATH = './scraped-images'

# %%
df_1 = pd.read_parquet("./food-ingredients/train-00000-of-00003.parquet")
df_2 = pd.read_parquet("./food-ingredients/train-00001-of-00003.parquet")
df_3 = pd.read_parquet("./food-ingredients/train-00002-of-00003.parquet")
df = pd.concat([df_1, df_2, df_3], axis=0)
df.head()

# %%
ingredients_categorical = list(set(list(zip(df['ingredient'].tolist(), df['subcategory'].tolist(), df['category'].tolist()))))
ingredients_categorical

# %%
queries = df['ingredient'].tolist()
queries = list(set(queries))
queries

# %%
regions = ["us-en", "uk-en", "au-en", "ca-en", "in-en", "ie-en", "nz-en", "sg-en", "za-en", "ph-en",
             "my-en", "id-en", "de-de", "fr-fr", "es-es", "it-it", "nl-nl", "ch-de", "ch-fr", "ch-it",
             "at-de", "be-fr", "be-nl", "se-sv", "no-no", "dk-da", "fi-fi", "pl-pl", "cz-cs", "hu-hu",
             "ro-ro", "sk-sk", "sl-sl", "hr-hr", "bg-bg", "ee-et", "lv-lv", "lt-lt", "gr-el", "ua-uk",
             "cn-zh", "jp-jp", "kr-kr", "hk-tzh", "tw-tzh", "th-th", "vn-vi", "id-id", "my-ms", "ph-tl",
             "il-he", "xa-ar", "br-pt", "mx-es", "ar-es", "cl-es", "co-es", "pe-es", "ve-es", "pt-pt",
             "ca-fr", "xl-es", "ue-es", "wt-wt", "ct-ca", "xa-en"]

# %%
page_nums = [i for i in range(5)]

# %%
def scrape_images_categorical(query, ingredient):
  name = query 
  print(name)
  query += ' ' + ingredient[1] + ' raw uncooked' #-cooked -vector -prepared
  
  with open('./progress.txt', 'r') as f:
    results = f.read().split('\n')
    length = len(name)
    count = [int(i.split(' ')[-1]) for i in results if i[:length] == name] 
    count = max(count) if count else 0
    print(count)
    f.close()

  with open('./urls.txt', 'r') as f:
    downloaded = set(f.read().split('\n'))

  num_idx = 0
  reg_idx = 0
  dir_path = os.path.join(PATH, f'{ingredient[0]}_{ingredient[1]}_{ingredient[2]}')
  os.makedirs(dir_path, exist_ok=True)

  while count < 100:
    try:
      results = DDGS().images(query=query, max_results=100, page=page_nums[num_idx], region=regions[reg_idx])
    except Exception as e:
      num_idx += 1
      if num_idx >= 5:
        reg_idx += 1
        num_idx = 0
        if reg_idx >= len(regions):
          print(e)
          print('Regions exhausted')

          with open('./progress.txt', 'r') as f:
            results = f.read().split('\n')
            length = len(name)
            idx = [results.index(i) for i in results if i[:length] == name]
            idx = max(idx) if idx else -1
            if idx != -1:
              results[idx] = f'{name} {count}'
            else:
              results.append(f'{name} {count}')
            f.close()

          with open('./progress.txt', 'w') as f:
            for i in results:
              f.write(i + '\n')
            f.close()

          break
      continue

    for each in results:
      if count >= 100:
        break

      try:
        data = fetch_image_bytes(each['image'])
        
        if data is None:
          continue
        if has_text(data):
          continue
        if each['image'] in downloaded:
          continue
        
        path = os.path.join(dir_path, f"{name}_{count + 1}.jpg")
        with open(path, 'wb') as f:
          f.write(data)

        with open('./urls.txt', 'a+') as f:
          f.write(each['image'] + '\n')
          f.close()
        downloaded.add(each['image'])

        count += 1
      except Exception as e:
        print(e)
        print(f'Failed to download {name} at {count + 1}')
        continue

    num_idx += 1
    if num_idx >= 5:
        reg_idx += 1
        num_idx = 0
    time.sleep(10)

  with open('./progress.txt', 'r') as f:
    results = f.read().split('\n')
    length = len(name)
    idx = [results.index(i) for i in results if i[:length] == name]
    idx = max(idx) if idx else -1
    if idx != -1:
      results[idx] = f'{name} {count}'
    else:
      results.append(f'{name} {count}')
    f.close()

  with open('./progress.txt', 'w') as f:
    for i in results:
      f.write(i + '\n')
    f.close()

# %%
try:
  scrape_images_categorical('spinach', ['spinach', 'leafy', 'vegetables']) #test query
except Exception as e:
  print(e)

# %%
  
progress_file = './progress.txt'
if os.path.exists(progress_file):
  with open(progress_file, 'r') as f:
    lines = f.read()
else:
  lines = ''
done = lines.split('\n')
for item in queries:
  if f'{item} 100' in done:
    continue
  full_ingredient = [[ingredients_categorical[i][0], ingredients_categorical[i][1], ingredients_categorical[i][2]] for i in range(len(ingredients_categorical)) if ingredients_categorical[i][0] == item]
  # print(full_ingredient)
  try:
    scrape_images_categorical(item, full_ingredient[0])
  except Exception as e:
    print(e)
  time.sleep(30)
# Out:
# lasagna
# 72
# ConnectError: ConnectError('error sending request for url (https://duckduckgo.com/?q=lasagna+types+raw+uncooked)', 'https://duckduckgo.com/?q=lasagna+types+raw+uncooked')
# Regions exhausted
# canned crab
# 0
# cannot identify image file <_io.BytesIO object at 0x0000024F03C53420>
# Failed to download canned crab at 6
# cannot identify image file <_io.BytesIO object at 0x0000024F03C618F0>
# Failed to download canned crab at 8
# cannot identify image file <_io.BytesIO object at 0x0000024EF2DED080>
# Failed to download canned crab at 9
# cannot identify image file <_io.BytesIO object at 0x0000024EF2DB5CB0>
# Failed to download canned crab at 10
# cannot identify image file <_io.BytesIO object at 0x0000024EFF7FF1F0>
# Failed to download canned crab at 17
# cannot identify image file <_io.BytesIO object at 0x0000024EFF7FF1A0>
# Failed to download canned crab at 23
# cannot identify image file <_io.BytesIO object at 0x0000024EFF7FF2E0>
# Failed to download canned crab at 24
# cannot identify image file <_io.BytesIO object at 0x0000024F03C2DCB0>
# Failed to download canned crab at 27
# cannot identify image file <_io.BytesIO object at 0x0000024EF2DB5B70>
# Failed to download canned crab at 29
# cannot identify image file <_io.BytesIO object at 0x0000024EFF7FF1A0>
# Failed to download canned crab at 34
# cannot identify image file <_io.BytesIO object at 0x0000024EFF80BD30>
# Failed to download canned crab at 41
# cannot identify image file <_io.BytesIO object at 0x0000024EFF71D9E0>
# Failed to download canned crab at 43
# cannot identify image file <_io.BytesIO object at 0x0000024EFF71CD60>
# Failed to download canned crab at 43
# cannot identify image file <_io.BytesIO object at 0x0000024EFF71CD60>
# Failed to download canned crab at 43
# cannot identify image file <_io.BytesIO object at 0x0000024F03C2F8D0>
# Failed to download canned crab at 44
# cannot identify image file <_io.BytesIO object at 0x0000024F03C2F8D0>
# Failed to download canned crab at 44
# cannot identify image file <_io.BytesIO object at 0x0000024F03C2E200>
# Failed to download canned crab at 45
# cannot identify image file <_io.BytesIO object at 0x0000024EF2DEE390>
# Failed to download canned crab at 56
# cannot identify image file <_io.BytesIO object at 0x0000024F03C534C0>
# Failed to download canned crab at 63
# cannot identify image file <_io.BytesIO object at 0x0000024F03C52CF0>
# Failed to download canned crab at 63
# garlic
# 0
# ConnectError: ConnectError('error sending request for url (https://duckduckgo.com/?q=garlic+allium+raw+uncooked)', 'https://duckduckgo.com/?q=garlic+allium+raw+uncooked')
# Regions exhausted
# canned oysters
# 0

# %% [markdown]
# # Canonical Ingredients

# %% [markdown]
# ### Drive File Access

# %%
from google.colab import drive
drive.mount('/content/gdrive')
PATH = '/content/gdrive/MyDrive/Scraped_Images'

# %%
df = pd.read_csv("/content/gdrive/My Drive/canonical_ingredients.csv")
df.head()

# %% [markdown]
# ### Local File Access

# %%
PATH = './scraped-images'

# %%
df = pd.read_csv('./canonical_ingredients.csv')
df.head()

# %%
ingredients_canonical = list(set(df['canonical_ingredient'].tolist()))
ingredients_canonical

# %%
def scrape_images_canonical(ingredient):
  print(ingredient)
  query = ingredient + ' raw ingredient uncooked' #-cooked -vector -prepared
  
  with open('./progress.txt', 'r') as f:
    results = f.read().split('\n')
    length = len(ingredient)
    count = [int(i.split(' ')[-1]) for i in results if i[:length] == ingredient] 
    count = max(count) if count else 0
    print(count)
    f.close()

  with open('./urls.txt', 'r') as f:
    downloaded = set(f.read().split('\n'))

  num_idx = 0
  reg_idx = 0
  dir_path = os.path.join(PATH, ingredient)
  os.makedirs(dir_path, exist_ok=True)

  while count < 100:
    try:
      results = DDGS().images(query=query, max_results=100, page=page_nums[num_idx], region=regions[reg_idx])
    except Exception as e:
      num_idx += 1
      if num_idx >= 5:
        reg_idx += 1
        num_idx = 0
        if reg_idx >= len(regions):
          print(e)
          print('Regions exhausted')

          with open('./progress.txt', 'r') as f:
            results = f.read().split('\n')
            length = len(ingredient)
            idx = [results.index(i) for i in results if i[:length] == ingredient]
            idx = max(idx) if idx else -1
            if idx != -1:
              results[idx] = f'{ingredient} {count}'
            else:
              results.append(f'{ingredient} {count}')
            f.close()

          with open('./progress.txt', 'w') as f:
            for i in results:
              f.write(i + '\n')
            f.close()

          break
      continue

    for each in results:
      if count >= 100:
        break

      try:
        data = fetch_image_bytes(each['image'])
        
        if data is None:
          continue
        if has_text(data):
          continue
        if each['image'] in downloaded:
          continue
        
        path = os.path.join(dir_path, f"{ingredient}_{count + 1}.jpg")
        with open(path, 'wb') as f:
          f.write(data)

        with open('./urls.txt', 'a+') as f:
          f.write(each['image'] + '\n')
          f.close()
        downloaded.add(each['image'])

        count += 1
      except Exception as e:
        print(e)
        print(f'Failed to download {ingredient} at {count + 1}')
        continue

    num_idx += 1
    if num_idx >= 5:
        reg_idx += 1
        num_idx = 0
    time.sleep(10)

  with open('./progress.txt', 'r') as f:
    results = f.read().split('\n')
    length = len(ingredient)
    idx = [results.index(i) for i in results if i[:length] == ingredient]
    idx = max(idx) if idx else -1
    if idx != -1:
      results[idx] = f'{ingredient} {count}'
    else:
      results.append(f'{ingredient} {count}')
    f.close()

  with open('./progress.txt', 'w') as f:
    for i in results:
      f.write(i + '\n')
    f.close()

# %%
try:
  scrape_images_canonical('spinach') #test query
except Exception as e:
  print(e)

# %%
  
progress_file = './progress.txt'
if os.path.exists(progress_file):
  with open(progress_file, 'r') as f:
    lines = f.read()
else:
  lines = ''
done = lines.split('\n')
for item in ingredients_canonical:
  if f'{item} 100' in done:
    continue
  try:
    scrape_images_canonical(item)
  except Exception as e:
    print(e)
  time.sleep(30)
